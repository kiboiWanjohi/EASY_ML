# %% [markdown]
# <a href="https://colab.research.google.com/github/ednamilgo/EASY_ML/blob/main/Python_1(e)_pandasipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # pandas

# %%
import pandas as pd

# %% [markdown]
# ## Creating a DataFrame

# %%
## From a dictionary

# %%
marks = {"Jane":[45,78,45,99,66],
        "Judy":[88,34,64,56,88],
        "Jack":[88,33,54,55,67],
        "James":[97,45,36,77,56],
        "John":[67,55,84,69,86]}
marks
# Out:
# {'Jane': [45, 78, 45, 99, 66],
#  'Judy': [88, 34, 64, 56, 88],
#  'Jack': [88, 33, 54, 55, 67],
#  'James': [97, 45, 36, 77, 56],
#  'John': [67, 55, 84, 69, 86]}

# %%
marks_df = pd.DataFrame(marks)
marks_df
# Out:
#    Jane  Judy  Jack  James  John
# 0    45    88    88     97    67
# 1    78    34    33     45    55
# 2    45    64    54     36    84
# 3    99    56    55     77    69
# 4    66    88    67     56    86

# %% [markdown]
# ## Dataframe with index

# %%
marks_df_2 = pd.DataFrame(marks, index=["maths", "Eng",'kis','agr','chem' ])
marks_df_2
# Out:
#        Jane  Judy  Jack  James  John
# maths    45    88    88     97    67
# Eng      78    34    33     45    55
# kis      45    64    54     36    84
# agr      99    56    55     77    69
# chem     66    88    67     56    86

# %%
pd.DataFrame.from_dict(marks, orient='columns', dtype=None, columns=None)
# Out:
#    Jane  Judy  Jack  James  John
# 0    45    88    88     97    67
# 1    78    34    33     45    55
# 2    45    64    54     36    84
# 3    99    56    55     77    69
# 4    66    88    67     56    86

# %% [markdown]
# ## from_dict

# %%
marks_df_3 = pd.DataFrame.from_dict(marks)
marks_df_3
# Out:
#    Jane  Judy  Jack  James  John
# 0    45    88    88     97    67
# 1    78    34    33     45    55
# 2    45    64    54     36    84
# 3    99    56    55     77    69
# 4    66    88    67     56    86

# %% [markdown]
# ## From DataSet

# %% [markdown]
# iris potatoes
# width of the leaf
# length of the leaf
# width of the flower
# length of the flower
#  iris sa

# %%
iris_df =  pd.read_csv("Iris.csv")

# %%
iris_df.head()# shows the first 5 trows
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_df.loc[1:4]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris_df.tail()# shows the last 5 trows
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris_df.info()# shows the the column names
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris_df.describe()# shows the  descriptive statistics from the data
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris_df.shape
# Out:
# (150, 6)

# %%
iris_df["Species"].nunique()
# Out:
# 3

# %%
iris_df["Species"].nunique()
# Out:
# 3

# %%
marks_df_3
# Out:
#    Jane  Judy  Jack  James  John
# 0    45    88    88     97    67
# 1    78    34    33     45    55
# 2    45    64    54     36    84
# 3    99    56    55     77    69
# 4    66    88    67     56    86

# %% [markdown]
# ## Adding a new column to a DataFrame

# %%
marks_df_3['Mike'] = [4,5,10,45,56]
marks_df_3
# Out:
#    Jane  Judy  Jack  James  John  Mike
# 0    45    88    88     97    67     4
# 1    78    34    33     45    55     5
# 2    45    64    54     36    84    10
# 3    99    56    55     77    69    45
# 4    66    88    67     56    86    56

# %% [markdown]
# ## Removing a column

# %%
marks_df_3.drop('James', axis=1)  # axis=1 for columns
# Out:
#    Jane  Judy  Jack  John  Mike
# 0    45    88    88    67     4
# 1    78    34    33    55     5
# 2    45    64    54    84    10
# 3    99    56    55    69    45
# 4    66    88    67    86    56

# %%
marks_df_3.loc[marks_df_3["Judy"] == 88, "Judy"] = 99 # Update Judy's 88 to  99
marks_df_3
# Out:
#    Jane  Judy  Jack  James  John  Mike
# 0    45    99    88     97    67     4
# 1    78    34    33     45    55     5
# 2    45    64    54     36    84    10
# 3    99    56    55     77    69    45
# 4    66    99    67     56    86    56

# %%
marks_df_3.iloc[1,2] = 11
marks_df_3
# Out:
#    Jane  Judy  Jack  James  John  Mike
# 0    45    99    88     97    67     4
# 1    78    34    11     45    55     5
# 2    45    64    54     36    84    10
# 3    99    56    55     77    69    45
# 4    66    99    67     56    86    56

# %% [markdown]
# # Filling missing values

# %%
df_data = pd.read_csv('data.csv')

# %%
df_data.isna().sum() # Count missing values
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
df_data.fillna(0, inplace=True)  # Replace NaN with 0

# %%
df_data = pd.read_csv('data.csv')

# %%
df_data.fillna(df_data.select_dtypes(include='number').mean(), inplace=True)  # Fill with mean

# %%
df_data.isna().sum() # Count missing values
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    0
# dtype: int64

# %% [markdown]
# ## Dropping the rows with missing values

# %%
df_data = pd.read_csv('data.csv')

# %%
df_data.dropna(inplace=True)

# %% [markdown]
# ## Saving a DataFrame

# %%
df_data.to_csv("output.csv", index=False)  # Save DataFrame to CSV
df_data.to_excel("output.xlsx", index=False)  # Save as Excel file
